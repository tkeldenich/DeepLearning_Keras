# %% [markdown]
# <a href="https://colab.research.google.com/github/tkeldenich/DeepLearning_Keras/blob/main/Le%C3%A7on_2_Ton_Premier_R%C3%A9seau_de_Neurones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !git clone https://github.com/tkeldenich/datasets.git
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 18 (delta 4), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (18/18), done.

# %%
df = pd.read_csv('datasets/fish.csv') 
df.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
df.Species = pd.Categorical(df.Species)
df['Species'] = df.Species.cat.codes

# %%
df = df.sample(frac=1).reset_index(drop=True)
df.head()
# Out:
#    Species  Weight  Length1  Length2  Length3   Height   Width
# 0        5    13.4     11.7     12.4     13.5   2.4300  1.2690
# 1        2   850.0     36.9     40.0     42.3  11.9286  7.1064
# 2        4   290.0     24.0     26.0     29.2   8.8768  4.4968
# 3        2    85.0     17.8     19.6     20.8   5.1376  3.0368
# 4        3   456.0     40.0     42.5     45.5   7.2800  4.3225

# %%
X = df.drop(['Weight'], axis=1)
Y = df['Weight']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# %%
''' model = Sequential()
model.add(Dense(15, input_dim=6, activation='relu'))
model.add(Dense(1, activation='linear')) '''

model = Sequential()
model.add(Dense(64, input_dim = 6, activation = 'relu'))
#model.add(Dense(64, activation = 'relu'))
#model.add(Dense(40, activation = 'relu'))
#model.add(Dense(54, activation = 'relu'))
model.add(Dense(1))

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mae'])

# %%
model.fit(X_train, Y_train, validation_split=0.2, epochs=200)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 3s 237ms/step - loss: 282375.5938 - mae: 401.7458 - val_loss: 350417.6875 - val_mae: 463.5791
# Epoch 2/200
# 4/4 [==============================] - 0s 35ms/step - loss: 279591.9688 - mae: 398.9857 - val_loss: 347223.3125 - val_mae: 460.8015
# Epoch 3/200
# 4/4 [==============================] - 0s 57ms/step - loss: 276702.6250 - mae: 396.2173 - val_loss: 344039.5000 - val_mae: 458.0210
# Epoch 4/200
# 4/4 [==============================] - 0s 45ms/step - loss: 273886.3438 - mae: 393.4546 - val_loss: 340808.6875 - val_mae: 455.1904
# Epoch 5/200
# 4/4 [==============================] - 0s 30ms/step - loss: 271012.5000 - mae: 390.6427 - val_loss: 337573.0312 - val_mae: 452.3359
# Epoch 6/200
# 4/4 [==============================] - 0s 34ms/step - loss: 268322.6875 - mae: 387.8275 - val_loss: 334348.8438 - val_mae: 449.4812
# Epoch 7/200
# ...
