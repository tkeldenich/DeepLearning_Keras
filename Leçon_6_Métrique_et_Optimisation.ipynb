# %% [markdown]
# <a href="https://colab.research.google.com/github/tkeldenich/DeepLearning_Keras/blob/main/Le%C3%A7on_6_M%C3%A9trique_et_Optimisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !git clone https://github.com/tkeldenich/datasets.git
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 18 (delta 4), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (18/18), done.

# %%
df = pd.read_csv('datasets/fish.csv') 
df.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
df.Species = pd.Categorical(df.Species)
df['Species'] = df.Species.cat.codes

# %%
df = df.sample(frac=1).reset_index(drop=True)
df.head()
# Out:
#    Species  Weight  Length1  Length2  Length3   Height   Width
# 0        3   500.0     42.0     45.0     48.0   6.9600  4.8960
# 1        4   120.0     19.4     21.0     23.7   6.1146  3.2943
# 2        2   514.0     30.5     32.8     34.0  10.0300  6.0180
# 3        2    85.0     17.8     19.6     20.8   5.1376  3.0368
# 4        3   345.0     36.0     38.5     41.0   6.3960  3.9770

# %%
X = df.drop(['Weight'], axis=1)
Y = df['Weight']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(64, input_dim = 6, activation = 'relu'))
model.add(Dense(1))

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mae'])

# %%
model.fit(X_train, Y_train, epochs=200)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 0s 9ms/step - loss: 50747.4883 - mae: 199.1771
# Epoch 2/200
# 4/4 [==============================] - 0s 5ms/step - loss: 50713.2344 - mae: 199.0840
# Epoch 3/200
# 4/4 [==============================] - 0s 7ms/step - loss: 50702.2773 - mae: 198.9830
# Epoch 4/200
# 4/4 [==============================] - 0s 9ms/step - loss: 50656.0820 - mae: 198.8769
# Epoch 5/200
# 4/4 [==============================] - 0s 10ms/step - loss: 50628.0234 - mae: 198.8244
# Epoch 6/200
# 4/4 [==============================] - 0s 4ms/step - loss: 50609.1875 - mae: 198.7672
# Epoch 7/200
# 4/4 [==============================] - 0s 6ms/step - loss: 50575.7578 - mae: 198.6952
# Epoch 8/200
# 4/4 [==============================] - 0s 3ms/step - loss: 50551.2852 - mae: 198.6018
# Epoch 9/200
# 4/4 [==============================] - 0s 3ms/step - loss: 50529.6523 - mae: 198.5626
# Epoch 10/200
# ...

# %%
scores = model.evaluate(X_test, Y_test, verbose = 0)

print('Mean Absolute Error : ', scores[1])
# Out:
# Mean Absolute Error :  139.67196655273438

# %%
Y_pred = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 23ms/step

# %%
from sklearn.metrics import r2_score

print('R2 score: ', r2_score(Y_test, Y_pred))
# Out:
# R2 score:  0.705119091787134
